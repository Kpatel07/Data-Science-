# %%
import urllib.request
from bs4 import BeautifulSoup
import requests
from bs4 import BeautifulSoup
import json
import bs4 as bs4
import urllib.request
import certifi
from urllib.request import Request, urlopen
data = []
imageFile = 'TennisPlayersss.json'

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "https://www.thefamouspeople.com/male-tennis-players.php"
headers = {'User-Agent':user_agent,}
request = urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
text = response.read()

soup = BeautifulSoup(text, "html.parser")

count = 0
loop = 150

# %%
for each_div in soup.findAll('div', {'class', 'col-md-4 col-sm-6 col-xs-12 col-lg-3 catprofiles'}):
#     print(each_div)
    img = each_div.findAll('img',data=True)
    print()

# %%
for each_div in soup.findAll('div', {'class', 'col-md-4 col-sm-6 col-xs-12 col-lg-3 catprofiles'}):
#     print(each_div)
    img = each_div.findAll('img',data=True)
    if len(img) > 0:
        print(img[0]["src"])

# %%
print("A")
# Out:
# A

# %%
for each_div in soup.findAll('div', {'class', 'col-md-4 col-sm-6 col-xs-12 col-lg-3 catprofiles'}):
#     print(each_div)
    
    img = each_div.findAll('img')
    if len(img) > 0:
        try:
            print(img[0]["data-src"])
        except:
            pass
# Out:
# //www.thefamouspeople.com/profiles/thumbs/boris-becker-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/leander-paes-2.jpg
# //www.thefamouspeople.com/profiles/thumbs/dean-paul-martin-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/ivan-lendl-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/mark-philippoussis-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/fred-perry-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/stefan-edberg-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/mats-wilander-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/jim-courier-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/pat-rafter-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/roy-emerson-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/don-budge-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/sascha-bajin-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/goran-ivanisevic-1.jpg
# //www.thefamouspeople.com/profiles/thumbs/sylvain-bruneau-1.jpg
# ...
